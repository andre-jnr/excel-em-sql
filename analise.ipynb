# %%
import pandas as pd

# %%
df = pd.read_excel("ESTOQUE PQ10 2025 NOVO.xlsx")

# %%
df.head()
# Out:
#     Código                           Descrição        Grupo  Estoque Unidade  \
# 0  22609.0    BALDE ESPUMANTE MOSCATEL 7x750ML      BEBIDAS     3.00      UN
# 1  12998.0  BACALHAU LOMBOS MORHUA SELECAO 1KG   CONGELADOS     8.00      UN
# 2   8469.0  LING FRANGO C/ BACON 600G NA BRASA    LINGUIÇAS    55.00      UN
# 3  12177.0   REQUEIJAO CREMOSO DANUBIO 1,010KG  LACTICINIOS    36.00      UN
# 4    654.0          COSTELA RECORT SALG AURORA        SUINO    68.13      KG
#
#     Custo  Custo Total
# 0  555.00    1665.0000
# 1  185.94    1487.5200
# 2   26.18    1439.9000
# 3   39.90    1436.4000
# 4   20.74    1413.0162

# %%
dados_lista = df.values.tolist()
print(dados_lista)
# Out:
# [[22609.0, 'BALDE ESPUMANTE MOSCATEL 7x750ML', 'BEBIDAS', 3.0, 'UN', 555.0, 1665.0], [12998.0, 'BACALHAU LOMBOS MORHUA SELECAO 1KG', 'CONGELADOS', 8.0, 'UN', 185.94, 1487.52], [8469.0, 'LING FRANGO C/ BACON 600G NA BRASA', 'LINGUIÇAS', 55.0, 'UN', 26.18, 1439.9], [12177.0, 'REQUEIJAO CREMOSO DANUBIO 1,010KG', 'LACTICINIOS', 36.0, 'UN', 39.9, 1436.3999999999999], [654.0, 'COSTELA RECORT SALG AURORA', 'SUINO', 68.13, 'KG', 20.74, 1413.0161999999998], [6843.0, 'PETIT GATEAU 4x60G', 'GONDOLAS', 48.0, 'UN', 29.19, 1401.1200000000001], [5106.0, 'LINGUIÇA CUIABANA FRANGO ESTRELA 600GR', 'LINGUIÇAS', 29.0, 'UN', 48.14, 1396.06], [20979.0, 'BACALHAU INFANTE IMP LOMBO 2KG', 'CONGELADOS', 6.05, 'KG', 230.56, 1394.888], [19740.0, 'CORAÇÃO DE FRANGO AMAZONAS', 'TEMPERADO DE FRANGO', 53.3, 'KG', 25.99, 1385.2669999999998], [17937.0, 'ASA 2JTA TULIPA FGO CONG SADIA PT 1KG', 'CONGELADOS', 80.0, 'CX', 17.31, 1384.8], [20256.0, 'LINGUIÇA  CUIABANA DE FRANGO', 'LINGUIÇAS', 36.0, 'KG', 38.33, 1379.87999
# ...
